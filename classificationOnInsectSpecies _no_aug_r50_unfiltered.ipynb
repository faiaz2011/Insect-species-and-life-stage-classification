# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
import pathlib
import glob
import itertools
import pandas as pd
#import splitfolders
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.layers import Conv2D, Flatten, Dense, MaxPooling2D, BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
from sklearn.metrics import classification_report
from mlxtend.plotting import plot_confusion_matrix

# %%
train_data_dir = r"D:/experiments/Datasets/ip102_v1.1-002/ip102_v1.1/prepared_data/train/"
valid_data_dir = r"D:/experiments/Datasets/ip102_v1.1-002/ip102_v1.1/prepared_data/val/"
test_data_dir = r"D:/experiments/Datasets/ip102_v1.1-002/ip102_v1.1/prepared_data/test/"

# %%
classes = ['rice leaf roller',
        'rice leaf caterpillar',
        'paddy stem maggot',
        'asiatic rice borer',
        'yellow rice borer',
        'rice gall midge',
        'Rice Stemfly',
        'brown plant hopper',
        'white backed plant hopper',
        'small brown plant hopper',
        'rice water weevil',
        'rice leafhopper',
        'grain spreader thrips',
        'rice shell pest',
        'grub',
        'mole cricket',
        'wireworm',
        'white margined moth',
        'black cutworm',
        'large cutworm',
        'yellow cutworm',
        'red spider',
        'corn borer',
        'army worm',
        'aphids',
        'Potosiabre vitarsis',
        'peach borer',
        'english grain aphid',
        'green bug',
        'bird cherry-oataphid',
        'wheat blossom midge',
        'penthaleus major',
        'longlegged spider mite',
        'wheat phloeothrips',
        'wheat sawfly',
        'cerodonta denticornis',
        'beet fly',
        'flea beetle',
        'cabbage army worm',
        'beet army worm',
        'Beet spot flies',
        'meadow moth',
        'beet weevil',
        'sericaorient alismots chulsky',
        'alfalfa weevil',
        'flax budworm',
        'alfalfa plant bug',
        'tarnished plant bug',
        'Locustoidea',
        'lytta polita',
        'legume blister beetle',
        'blister beetle',
        'therioaphis maculata Buckton',
        'odontothrips loti',
        'Thrips',
        'alfalfa seed chalcid',
        'Pieris canidia',
        'Apolygus lucorum',
        'Limacodidae',
        'Viteus vitifoliae',
        'Colomerus vitis',
        'Brevipoalpus lewisi McGregor',
        'oides decempunctata',
        'Polyphagotars onemus latus',
        'Pseudococcus comstocki Kuwana',
        'parathrene regalis',
        'Ampelophaga',
        'Lycorma delicatula',
        'Xylotrechus',
        'Cicadella viridis',
        'Miridae',
        'Trialeurodes vaporariorum',
        'Erythroneura apicalis',
        'Papilio xuthus',
        'Panonchus citri McGregor',
        'Phyllocoptes oleiverus ashmead',
        'Icerya purchasi Maskell',
        'Unaspis yanonensis',
        'Ceroplastes rubens',
        'Chrysomphalus aonidum',
        'Parlatoria zizyphus Lucus',
        'Nipaecoccus vastalor',
        'Aleurocanthus spiniferus',
        'Tetradacus c Bactrocera minax',
        'Dacus dorsalis(Hendel)',
        'Bactrocera tsuneonis',
        'Prodenia litura',
        'Adristyrannus',
        'Phyllocnistis citrella Stainton',
        'Toxoptera citricidus',
        'Toxoptera aurantii',
        'Aphis citricola Vander Goot',
        'Scirtothrips dorsalis Hood',
        'Dasineura sp',
        'Lawana imitata Melichar',
        'Salurnis marginella Guerr',
        'Deporaus marginatus Pascoe',
        'Chlumetia transversa',
        'Mango flat beak leafhopper',
        'Rhytidodera bowrinii white',
        'Sternochetus frigidus',
        'Cicadellidae'
]

# %% [markdown]
# # ResNet50

# %%
# datagen = ImageDataGenerator(
#     preprocessing_function=tf.keras.applications.resnet50.preprocess_input,
#     rescale=1./255,
#     rotation_range=20,
#     width_shift_range=0.1,
#     height_shift_range=0.1,
#     shear_range=0.1,
#     zoom_range=0.1,
#     horizontal_flip=True,
#     fill_mode='nearest'
# )

# %%
datagen = ImageDataGenerator()

# %%
train_batchs_Res = datagen.flow_from_directory(directory=train_data_dir, target_size=(224,224), classes=classes, batch_size=64)

valid_batchs_Res = datagen.flow_from_directory(directory=valid_data_dir, target_size=(224,224), classes=classes, batch_size=64)

test_batchs_Res = datagen.flow_from_directory(directory=test_data_dir, target_size=(224,224), classes=classes, batch_size=64, shuffle=False)
# Out:
# Found 45095 images belonging to 102 classes.
# Found 7508 images belonging to 102 classes.
# Found 22619 images belonging to 102 classes.

# %%
base_model_Res = ResNet50(include_top = False, weights = 'imagenet')

# %%
x = base_model_Res.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)

predictions = Dense(train_batchs_Res.num_classes, activation='softmax')(x)

modelRes = Model(inputs=base_model_Res.input, outputs=predictions)

for layer in base_model_Res.layers:
    layer.trainable = True

# %%
modelRes.compile(optimizer = Adam(learning_rate=0.0001), loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
callbacks = [
        ModelCheckpoint("SavedModels/resnet_50_model/model_resnet50_unfiltered.h5", verbose=1, save_best_model=True),
        ReduceLROnPlateau(monitor="val_loss", patience=3, factor=0.1, verbose=1, min_lr=1e-6),
        EarlyStopping(monitor="val_loss", patience=5, verbose=1)
    ]

# %%
history_Res = modelRes.fit(x = train_batchs_Res, 
            steps_per_epoch=train_batchs_Res.samples // 64,
            validation_data = valid_batchs_Res,
            validation_steps=valid_batchs_Res.samples // 64,
            epochs = 500, verbose = 1,
            callbacks=callbacks,)
# Out:
# Epoch 1/500
# 704/704 [==============================] - ETA: 0s - loss: 2.0561 - accuracy: 0.4987
# Epoch 1: saving model to SavedModels/resnet_50_model\model_resnet50_unfiltered.h5
# 704/704 [==============================] - 611s 862ms/step - loss: 2.0561 - accuracy: 0.4987 - val_loss: 1.6245 - val_accuracy: 0.5705 - lr: 1.0000e-04
# Epoch 2/500
# 704/704 [==============================] - ETA: 0s - loss: 1.0484 - accuracy: 0.7080
# Epoch 2: saving model to SavedModels/resnet_50_model\model_resnet50_unfiltered.h5
# 704/704 [==============================] - 97s 137ms/step - loss: 1.0484 - accuracy: 0.7080 - val_loss: 1.5620 - val_accuracy: 0.5903 - lr: 1.0000e-04
# Epoch 3/500
# 704/704 [==============================] - ETA: 0s - loss: 0.6170 - accuracy: 0.8158
# Epoch 3: saving model to SavedModels/resnet_50_model\model_resnet50_unfiltered.h5
# 704/704 [==============================] - 96s 136ms/step - loss: 0.6170 - accuracy: 0.8158 - val_loss: 1.6648 - val_accuracy: 0.5984 - lr: 1.0000e-04
# Epoch 4/500
# 704/704 [==============================] - ETA: 0s - loss: 0.3793 - accuracy: 0.8831
# Epoch 4: saving model to SavedModels/resnet_50_model\model_resnet50_unfiltered.h5
# 704/704 [==============================] - 96s 136ms/step - loss: 0.3793 - accuracy: 0.8831 - val_loss: 1.6592 - val_accuracy: 0.6123 - lr: 1.0000e-04
# Epoch 5/500
# 704/704 [==============================] - ETA: 0s - loss: 0.2648 - accuracy: 0.9181
# Epoch 5: saving model to SavedModels/resnet_50_model\model_resnet50_unfiltered.h5
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 704/704 [==============================] - 96s 136ms/step - loss: 0.2648 - accuracy: 0.9181 - val_loss: 1.7546 - val_accuracy: 0.6099 - lr: 1.0000e-04
# Epoch 6/500
# 704/704 [==============================] - ETA: 0s - loss: 0.1011 - accuracy: 0.9738
# Epoch 6: saving model to SavedModels/resnet_50_model\model_resnet50_unfiltered.h5
# 704/704 [==============================] - 96s 136ms/step - loss: 0.1011 - accuracy: 0.9738 - val_loss: 1.4365 - val_accuracy: 0.6896 - lr: 1.0000e-05
# Epoch 7/500
# 704/704 [==============================] - ETA: 0s - loss: 0.0421 - accuracy: 0.9926
# Epoch 7: saving model to SavedModels/resnet_50_model\model_resnet50_unfiltered.h5
# 704/704 [==============================] - 96s 136ms/step - loss: 0.0421 - accuracy: 0.9926 - val_loss: 1.4750 - val_accuracy: 0.6940 - lr: 1.0000e-05
# Epoch 8/500
# 704/704 [==============================] - ETA: 0s - loss: 0.0251 - accuracy: 0.9972
# Epoch 8: saving model to SavedModels/resnet_50_model\model_resnet50_unfiltered.h5
# 704/704 [==============================] - 96s 136ms/step - loss: 0.0251 - accuracy: 0.9972 - val_loss: 1.5083 - val_accuracy: 0.6930 - lr: 1.0000e-05
# Epoch 9/500
# 704/704 [==============================] - ETA: 0s - loss: 0.0155 - accuracy: 0.9991
# Epoch 9: saving model to SavedModels/resnet_50_model\model_resnet50_unfiltered.h5
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 1e-06.
# 704/704 [==============================] - 96s 136ms/step - loss: 0.0155 - accuracy: 0.9991 - val_loss: 1.5601 - val_accuracy: 0.6923 - lr: 1.0000e-05
# Epoch 10/500
# 704/704 [==============================] - ETA: 0s - loss: 0.0101 - accuracy: 0.9998
# Epoch 10: saving model to SavedModels/resnet_50_model\model_resnet50_unfiltered.h5
# 704/704 [==============================] - 96s 136ms/step - loss: 0.0101 - accuracy: 0.9998 - val_loss: 1.5622 - val_accuracy: 0.6934 - lr: 1.0000e-06
# Epoch 11/500
# 704/704 [==============================] - ETA: 0s - loss: 0.0093 - accuracy: 0.9999
# Epoch 11: saving model to SavedModels/resnet_50_model\model_resnet50_unfiltered.h5
# 704/704 [==============================] - 96s 136ms/step - loss: 0.0093 - accuracy: 0.9999 - val_loss: 1.5704 - val_accuracy: 0.6944 - lr: 1.0000e-06
# Epoch 11: early stopping

# %%
Res_model = tf.keras.models.load_model('SavedModels/resnet_50_model/model_resnet50_unfiltered.h5')

Res_predictions = Res_model.predict(x=test_batchs_Res, verbose=0)

# %%
y_pred_Res = np.argmax(Res_predictions, axis=1)
y_true_Res = test_batchs_Res.classes

precision = precision_score(y_true_Res, y_pred_Res, average='weighted', zero_division=0)
print('Precision: %f' % precision)

recall = recall_score(y_true_Res, y_pred_Res, average='weighted', zero_division=0)
print('Recall: %f' % recall)

f1 = f1_score(y_true_Res, y_pred_Res, average='weighted', zero_division=0)
print('F1 score: %f' % f1)

accuracy = accuracy_score(y_true_Res, y_pred_Res)
print('Accuracy: %f' % accuracy)
# Out:
# Precision: 0.686969
# Recall: 0.688801
# F1 score: 0.686503
# Accuracy: 0.688801

# %%
print(classification_report(y_true_Res, y_pred_Res, target_names = classes, zero_division=0))
# Out:
#                                  precision    recall  f1-score   support
#
#                rice leaf roller       0.66      0.78      0.71       335
#           rice leaf caterpillar       0.45      0.47      0.46       147
#               paddy stem maggot       0.54      0.41      0.46        79
#              asiatic rice borer       0.57      0.59      0.58       316
#               yellow rice borer       0.59      0.58      0.59       152
#                 rice gall midge       0.67      0.73      0.70       152
#                    Rice Stemfly       0.59      0.61      0.60       111
#              brown plant hopper       0.51      0.47      0.49       251
#       white backed plant hopper       0.44      0.50      0.47       268
#        small brown plant hopper       0.47      0.48      0.47       166
#               rice water weevil       0.81      0.74      0.77       257
#                 rice leafhopper       0.46      0.39      0.42       122
#           grain spreader thrips       0.54      0.50      0.52        52
#                 rice shell pest       0.57      0.42      0.48       123
#                            grub       0.84      0.85      0.85       258
#                    mole cricket       0.91      0.94      0.92       495
#                        wireworm       0.81      0.78      0.79       267
#             white margined moth       0.38      0.44      0.41        45
#                   black cutworm       0.54      0.55      0.55       257
#                   large cutworm       0.25      0.27      0.26       148
#                  yellow cutworm       0.37      0.36      0.37       144
#                      red spider       0.57      0.55      0.56       159
#                      corn borer       0.69      0.69      0.69       510
#                       army worm       0.50      0.49      0.50       322
#                          aphids       0.68      0.75      0.71      1229
#             Potosiabre vitarsis       0.88      0.86      0.87       170
#                     peach borer       0.81      0.77      0.79       208
#             english grain aphid       0.44      0.36      0.39       197
#                       green bug       0.32      0.24      0.28        98
#            bird cherry-oataphid       0.37      0.39      0.38       213
#             wheat blossom midge       0.89      0.92      0.91       146
#                penthaleus major       0.70      0.46      0.55        70
#          longlegged spider mite       0.47      0.46      0.47        74
#              wheat phloeothrips       0.55      0.65      0.60        88
#                    wheat sawfly       0.82      0.62      0.70       102
#           cerodonta denticornis       0.59      0.45      0.51        42
#                        beet fly       0.56      0.31      0.40        32
#                     flea beetle       0.84      0.78      0.81       237
#               cabbage army worm       0.41      0.41      0.41       257
#                  beet army worm       0.53      0.58      0.55       482
#                 Beet spot flies       0.62      0.64      0.63        90
#                     meadow moth       0.81      0.68      0.74        81
#                     beet weevil       0.53      0.55      0.54        93
#   sericaorient alismots chulsky       0.87      0.69      0.77        58
#                  alfalfa weevil       0.59      0.54      0.56       158
#                    flax budworm       0.44      0.42      0.43       320
#               alfalfa plant bug       0.51      0.42      0.46       197
#             tarnished plant bug       0.57      0.50      0.54       246
#                     Locustoidea       0.86      0.87      0.86       419
#                    lytta polita       0.57      0.49      0.53       197
#           legume blister beetle       0.70      0.73      0.72       423
#                  blister beetle       0.62      0.62      0.62       570
#    therioaphis maculata Buckton       0.25      0.14      0.18        78
#               odontothrips loti       0.64      0.52      0.57        54
#                          Thrips       0.39      0.38      0.39       264
#            alfalfa seed chalcid       0.39      0.39      0.39        56
#                  Pieris canidia       0.92      0.92      0.92       141
#                Apolygus lucorum       0.40      0.37      0.38       115
#                     Limacodidae       0.87      0.85      0.86       421
#               Viteus vitifoliae       0.60      0.64      0.62       107
#                 Colomerus vitis       0.64      0.64      0.64        53
#    Brevipoalpus lewisi McGregor       0.82      0.75      0.78        24
#             oides decempunctata       0.90      0.92      0.91        85
#      Polyphagotars onemus latus       0.29      0.23      0.26        26
#   Pseudococcus comstocki Kuwana       0.61      0.60      0.61        93
#              parathrene regalis       0.74      0.67      0.70        42
#                     Ampelophaga       0.83      0.70      0.76       230
#              Lycorma delicatula       0.84      0.87      0.85      1594
#                     Xylotrechus       0.85      0.81      0.83       345
#               Cicadella viridis       0.80      0.76      0.78       384
#                         Miridae       0.75      0.81      0.78      1525
#       Trialeurodes vaporariorum       0.72      0.73      0.73       208
#           Erythroneura apicalis       0.68      0.68      0.68        22
#                  Papilio xuthus       0.91      0.94      0.93       135
#        Panonchus citri McGregor       0.63      0.72      0.67       116
#  Phyllocoptes oleiverus ashmead       0.74      0.65      0.69        52
#         Icerya purchasi Maskell       0.78      0.75      0.77       217
#              Unaspis yanonensis       0.61      0.67      0.64       126
#              Ceroplastes rubens       0.79      0.82      0.81        78
#           Chrysomphalus aonidum       0.72      0.69      0.71        68
#       Parlatoria zizyphus Lucus       0.80      0.52      0.63        23
#            Nipaecoccus vastalor       0.54      0.50      0.52        30
#        Aleurocanthus spiniferus       0.89      0.89      0.89       208
#   Tetradacus c Bactrocera minax       0.74      0.74      0.74       117
#          Dacus dorsalis(Hendel)       0.65      0.67      0.66       132
#            Bactrocera tsuneonis       0.58      0.37      0.45        51
#                 Prodenia litura       0.66      0.62      0.64       392
#                   Adristyrannus       0.73      0.64      0.68        94
# Phyllocnistis citrella Stainton       0.74      0.73      0.73       122
#            Toxoptera citricidus       0.41      0.42      0.42        57
#              Toxoptera aurantii       0.71      0.51      0.60        68
#     Aphis citricola Vander Goot       0.62      0.67      0.65       106
#      Scirtothrips dorsalis Hood       0.67      0.70      0.68       243
#                    Dasineura sp       0.48      0.51      0.50       152
#         Lawana imitata Melichar       0.74      0.79      0.76       174
#       Salurnis marginella Guerr       0.75      0.77      0.76       147
#      Deporaus marginatus Pascoe       0.65      0.51      0.57        63
#            Chlumetia transversa       0.51      0.55      0.53        92
#      Mango flat beak leafhopper       0.50      0.29      0.36        28
#      Rhytidodera bowrinii white       0.67      0.67      0.67       167
#           Sternochetus frigidus       0.62      0.64      0.63       138
#                    Cicadellidae       0.83      0.85      0.84      1723
#
#                        accuracy                           0.69     22619
#                       macro avg       0.64      0.61      0.62     22619
#                    weighted avg       0.69      0.69      0.69     22619

# %%
#Get the filename including last folder
image_names = [os.path.basename(filename) for filename in test_batchs_Res.filenames]


# Get the image names from the ImageDataGenerator
image_names = test_batchs_Res.filenames

df = pd.DataFrame({'Image Name': image_names, 'Predicted': y_pred_Res, 'Ground Truth': y_true_Res})
df.to_csv('results_R50_cls_no_aug_unfiltered.csv', index=False)

# %%
matRes = confusion_matrix(y_true_Res,y_pred_Res)
plot_confusion_matrix(matRes, figsize=(36,36), class_names=classes, show_normed=True)
# Out:
# (<Figure size 3600x3600 with 1 Axes>,
#  <Axes: xlabel='predicted label', ylabel='true label'>)
