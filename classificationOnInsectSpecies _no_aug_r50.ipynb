# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
import pathlib
import glob
import itertools
import pandas as pd
#import splitfolders
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.layers import Conv2D, Flatten, Dense, MaxPooling2D, BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
from sklearn.metrics import classification_report
from mlxtend.plotting import plot_confusion_matrix

# %%
train_data_dir = r"D:/experiments/Datasets/ip102_v1.1-002/ip102_v1.1/prepared_data/train_all/"
valid_data_dir = r"D:/experiments/Datasets/ip102_v1.1-002/ip102_v1.1/prepared_data/val_all/"
test_data_dir = r"D:/experiments/Datasets/ip102_v1.1-002/ip102_v1.1/prepared_data/test_all/"

# %%
classes = ['rice leaf roller',
        'rice leaf caterpillar',
        'paddy stem maggot',
        'asiatic rice borer',
        'yellow rice borer',
        'rice gall midge',
        'Rice Stemfly',
        'brown plant hopper',
        'white backed plant hopper',
        'small brown plant hopper',
        'rice water weevil',
        'rice leafhopper',
        'grain spreader thrips',
        'rice shell pest',
        'grub',
        'mole cricket',
        'wireworm',
        'white margined moth',
        'black cutworm',
        'large cutworm',
        'yellow cutworm',
        'red spider',
        'corn borer',
        'army worm',
        'aphids',
        'Potosiabre vitarsis',
        'peach borer',
        'english grain aphid',
        'green bug',
        'bird cherry-oataphid',
        'wheat blossom midge',
        'penthaleus major',
        'longlegged spider mite',
        'wheat phloeothrips',
        'wheat sawfly',
        'cerodonta denticornis',
        'beet fly',
        'flea beetle',
        'cabbage army worm',
        'beet army worm',
        'Beet spot flies',
        'meadow moth',
        'beet weevil',
        'sericaorient alismots chulsky',
        'alfalfa weevil',
        'flax budworm',
        'alfalfa plant bug',
        'tarnished plant bug',
        'Locustoidea',
        'lytta polita',
        'legume blister beetle',
        'blister beetle',
        'therioaphis maculata Buckton',
        'odontothrips loti',
        'Thrips',
        'alfalfa seed chalcid',
        'Pieris canidia',
        'Apolygus lucorum',
        'Limacodidae',
        'Viteus vitifoliae',
        'Colomerus vitis',
        'Brevipoalpus lewisi McGregor',
        'oides decempunctata',
        'Polyphagotars onemus latus',
        'Pseudococcus comstocki Kuwana',
        'parathrene regalis',
        'Ampelophaga',
        'Lycorma delicatula',
        'Xylotrechus',
        'Cicadella viridis',
        'Miridae',
        'Trialeurodes vaporariorum',
        'Erythroneura apicalis',
        'Papilio xuthus',
        'Panonchus citri McGregor',
        'Phyllocoptes oleiverus ashmead',
        'Icerya purchasi Maskell',
        'Unaspis yanonensis',
        'Ceroplastes rubens',
        'Chrysomphalus aonidum',
        'Parlatoria zizyphus Lucus',
        'Nipaecoccus vastalor',
        'Aleurocanthus spiniferus',
        'Tetradacus c Bactrocera minax',
        'Dacus dorsalis(Hendel)',
        'Bactrocera tsuneonis',
        'Prodenia litura',
        'Adristyrannus',
        'Phyllocnistis citrella Stainton',
        'Toxoptera citricidus',
        'Toxoptera aurantii',
        'Aphis citricola Vander Goot',
        'Scirtothrips dorsalis Hood',
        'Dasineura sp',
        'Lawana imitata Melichar',
        'Salurnis marginella Guerr',
        'Deporaus marginatus Pascoe',
        'Chlumetia transversa',
        'Mango flat beak leafhopper',
        'Rhytidodera bowrinii white',
        'Sternochetus frigidus',
        'Cicadellidae'
]

# %% [markdown]
# # ResNet50

# %%
# datagen = ImageDataGenerator(
#     preprocessing_function=tf.keras.applications.resnet50.preprocess_input,
#     rescale=1./255,
#     rotation_range=20,
#     width_shift_range=0.1,
#     height_shift_range=0.1,
#     shear_range=0.1,
#     zoom_range=0.1,
#     horizontal_flip=True,
#     fill_mode='nearest'
# )

# %%
datagen = ImageDataGenerator()

# %%
train_batchs_Res = datagen.flow_from_directory(directory=train_data_dir, target_size=(224,224), classes=classes, batch_size=64)

valid_batchs_Res = datagen.flow_from_directory(directory=valid_data_dir, target_size=(224,224), classes=classes, batch_size=64)

test_batchs_Res = datagen.flow_from_directory(directory=test_data_dir, target_size=(224,224), classes=classes, batch_size=64, shuffle=False)
# Out:
# Found 38400 images belonging to 102 classes.
# Found 6352 images belonging to 102 classes.
# Found 20047 images belonging to 102 classes.

# %%
base_model_Res = ResNet50(include_top = False, weights = 'imagenet')

# %%
x = base_model_Res.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)

predictions = Dense(train_batchs_Res.num_classes, activation='softmax')(x)

modelRes = Model(inputs=base_model_Res.input, outputs=predictions)

for layer in base_model_Res.layers:
    layer.trainable = True

# %%
modelRes.compile(optimizer = Adam(learning_rate=0.0001), loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
callbacks = [
        ModelCheckpoint("SavedModels/resnet_50_model/model_resnet50.h5", verbose=1, save_best_model=True),
        ReduceLROnPlateau(monitor="val_loss", patience=3, factor=0.1, verbose=1, min_lr=1e-6),
        EarlyStopping(monitor="val_loss", patience=5, verbose=1)
    ]

# %%
history_Res = modelRes.fit(x = train_batchs_Res, 
            steps_per_epoch=train_batchs_Res.samples // 64,
            validation_data = valid_batchs_Res,
            validation_steps=valid_batchs_Res.samples // 64,
            epochs = 500, verbose = 1,
            callbacks=callbacks,)
# Out:
# Epoch 1/500
# 600/600 [==============================] - ETA: 0s - loss: 1.8809 - accuracy: 0.5403
# Epoch 1: saving model to SavedModels/resnet_50_model\model_resnet50.h5
# 600/600 [==============================] - 88s 141ms/step - loss: 1.8809 - accuracy: 0.5403 - val_loss: 1.4930 - val_accuracy: 0.6111 - lr: 1.0000e-04
# Epoch 2/500
# 600/600 [==============================] - ETA: 0s - loss: 0.8905 - accuracy: 0.7474
# Epoch 2: saving model to SavedModels/resnet_50_model\model_resnet50.h5
# 600/600 [==============================] - 87s 144ms/step - loss: 0.8905 - accuracy: 0.7474 - val_loss: 1.4026 - val_accuracy: 0.6416 - lr: 1.0000e-04
# Epoch 3/500
# 600/600 [==============================] - ETA: 0s - loss: 0.4914 - accuracy: 0.8512
# Epoch 3: saving model to SavedModels/resnet_50_model\model_resnet50.h5
# 600/600 [==============================] - 84s 140ms/step - loss: 0.4914 - accuracy: 0.8512 - val_loss: 1.4659 - val_accuracy: 0.6430 - lr: 1.0000e-04
# Epoch 4/500
# 600/600 [==============================] - ETA: 0s - loss: 0.2891 - accuracy: 0.9093
# Epoch 4: saving model to SavedModels/resnet_50_model\model_resnet50.h5
# 600/600 [==============================] - 87s 144ms/step - loss: 0.2891 - accuracy: 0.9093 - val_loss: 1.5810 - val_accuracy: 0.6395 - lr: 1.0000e-04
# Epoch 5/500
# 600/600 [==============================] - ETA: 0s - loss: 0.2044 - accuracy: 0.9361
# Epoch 5: saving model to SavedModels/resnet_50_model\model_resnet50.h5
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 600/600 [==============================] - 94s 157ms/step - loss: 0.2044 - accuracy: 0.9361 - val_loss: 1.7234 - val_accuracy: 0.6452 - lr: 1.0000e-04
# Epoch 6/500
# 600/600 [==============================] - ETA: 0s - loss: 0.0841 - accuracy: 0.9781
# Epoch 6: saving model to SavedModels/resnet_50_model\model_resnet50.h5
# 600/600 [==============================] - 86s 142ms/step - loss: 0.0841 - accuracy: 0.9781 - val_loss: 1.3596 - val_accuracy: 0.7049 - lr: 1.0000e-05
# Epoch 7/500
# 600/600 [==============================] - ETA: 0s - loss: 0.0334 - accuracy: 0.9945
# Epoch 7: saving model to SavedModels/resnet_50_model\model_resnet50.h5
# 600/600 [==============================] - 85s 141ms/step - loss: 0.0334 - accuracy: 0.9945 - val_loss: 1.3844 - val_accuracy: 0.7068 - lr: 1.0000e-05
# Epoch 8/500
# 600/600 [==============================] - ETA: 0s - loss: 0.0193 - accuracy: 0.9983
# Epoch 8: saving model to SavedModels/resnet_50_model\model_resnet50.h5
# 600/600 [==============================] - 84s 141ms/step - loss: 0.0193 - accuracy: 0.9983 - val_loss: 1.4287 - val_accuracy: 0.7104 - lr: 1.0000e-05
# Epoch 9/500
# 600/600 [==============================] - ETA: 0s - loss: 0.0127 - accuracy: 0.9993
# Epoch 9: saving model to SavedModels/resnet_50_model\model_resnet50.h5
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 1e-06.
# 600/600 [==============================] - 83s 139ms/step - loss: 0.0127 - accuracy: 0.9993 - val_loss: 1.4565 - val_accuracy: 0.7118 - lr: 1.0000e-05
# Epoch 10/500
# 600/600 [==============================] - ETA: 0s - loss: 0.0086 - accuracy: 0.9998
# Epoch 10: saving model to SavedModels/resnet_50_model\model_resnet50.h5
# 600/600 [==============================] - 83s 138ms/step - loss: 0.0086 - accuracy: 0.9998 - val_loss: 1.4666 - val_accuracy: 0.7131 - lr: 1.0000e-06
# Epoch 11/500
# 600/600 [==============================] - ETA: 0s - loss: 0.0080 - accuracy: 0.9999
# Epoch 11: saving model to SavedModels/resnet_50_model\model_resnet50.h5
# 600/600 [==============================] - 83s 139ms/step - loss: 0.0080 - accuracy: 0.9999 - val_loss: 1.4700 - val_accuracy: 0.7132 - lr: 1.0000e-06
# Epoch 11: early stopping

# %%
Res_model = tf.keras.models.load_model('SavedModels/resnet_50_model/model_resnet50.h5')

Res_predictions = Res_model.predict(x=test_batchs_Res, verbose=0)

# %%
y_pred_Res = np.argmax(Res_predictions, axis=1)
y_true_Res = test_batchs_Res.classes

precision = precision_score(y_true_Res, y_pred_Res, average='weighted', zero_division=0)
print('Precision: %f' % precision)

recall = recall_score(y_true_Res, y_pred_Res, average='weighted', zero_division=0)
print('Recall: %f' % recall)

f1 = f1_score(y_true_Res, y_pred_Res, average='weighted', zero_division=0)
print('F1 score: %f' % f1)

accuracy = accuracy_score(y_true_Res, y_pred_Res)
print('Accuracy: %f' % accuracy)
# Out:
# Precision: 0.694199
# Recall: 0.697860
# F1 score: 0.692251
# Accuracy: 0.697860

# %%
print(classification_report(y_true_Res, y_pred_Res, target_names = classes, zero_division=0))
# Out:
#                                  precision    recall  f1-score   support
#
#                rice leaf roller       0.65      0.83      0.73       226
#           rice leaf caterpillar       0.62      0.49      0.55       110
#               paddy stem maggot       0.62      0.31      0.41        42
#              asiatic rice borer       0.66      0.62      0.64       207
#               yellow rice borer       0.61      0.71      0.66       116
#                 rice gall midge       0.81      0.78      0.80       110
#                    Rice Stemfly       0.63      0.64      0.63        61
#              brown plant hopper       0.65      0.44      0.52       186
#       white backed plant hopper       0.59      0.65      0.62       164
#        small brown plant hopper       0.56      0.48      0.52        91
#               rice water weevil       0.76      0.69      0.72       171
#                 rice leafhopper       0.41      0.49      0.45       109
#           grain spreader thrips       0.55      0.58      0.56        52
#                 rice shell pest       0.57      0.41      0.48        76
#                            grub       0.80      0.89      0.84       253
#                    mole cricket       0.92      0.94      0.93       483
#                        wireworm       0.82      0.82      0.82       222
#             white margined moth       0.45      0.50      0.48        38
#                   black cutworm       0.54      0.54      0.54       211
#                   large cutworm       0.29      0.27      0.28       132
#                  yellow cutworm       0.36      0.38      0.37       125
#                      red spider       0.58      0.61      0.59       150
#                      corn borer       0.68      0.71      0.69       375
#                       army worm       0.56      0.53      0.55       275
#                          aphids       0.67      0.76      0.71      1229
#             Potosiabre vitarsis       0.88      0.87      0.87       169
#                     peach borer       0.79      0.75      0.77       186
#             english grain aphid       0.38      0.36      0.37       197
#                       green bug       0.29      0.29      0.29        98
#            bird cherry-oataphid       0.36      0.40      0.38       213
#             wheat blossom midge       0.86      0.77      0.81       117
#                penthaleus major       0.74      0.51      0.60        63
#          longlegged spider mite       0.52      0.43      0.47        51
#              wheat phloeothrips       0.62      0.65      0.63        77
#                    wheat sawfly       0.78      0.66      0.71        93
#           cerodonta denticornis       0.52      0.47      0.49        32
#                        beet fly       0.41      0.36      0.38        25
#                     flea beetle       0.80      0.79      0.79       237
#               cabbage army worm       0.38      0.40      0.39       227
#                  beet army worm       0.55      0.58      0.57       357
#                 Beet spot flies       0.68      0.55      0.61        65
#                     meadow moth       0.68      0.67      0.67        72
#                     beet weevil       0.51      0.54      0.52        93
#   sericaorient alismots chulsky       0.73      0.65      0.69        51
#                  alfalfa weevil       0.50      0.47      0.48       120
#                    flax budworm       0.39      0.41      0.40       284
#               alfalfa plant bug       0.46      0.41      0.44       197
#             tarnished plant bug       0.58      0.46      0.51       237
#                     Locustoidea       0.89      0.88      0.88       419
#                    lytta polita       0.53      0.48      0.50       197
#           legume blister beetle       0.70      0.74      0.72       423
#                  blister beetle       0.62      0.63      0.62       569
#    therioaphis maculata Buckton       0.17      0.15      0.16        48
#               odontothrips loti       0.67      0.54      0.60        54
#                          Thrips       0.37      0.26      0.31        72
#            alfalfa seed chalcid       0.38      0.45      0.41        53
#                  Pieris canidia       0.90      0.92      0.91       141
#                Apolygus lucorum       0.37      0.48      0.42       102
#                     Limacodidae       0.86      0.90      0.88       413
#               Viteus vitifoliae       0.33      0.01      0.02        94
#                 Colomerus vitis       0.00      0.00      0.00        35
#    Brevipoalpus lewisi McGregor       0.67      0.22      0.33         9
#             oides decempunctata       0.92      0.92      0.92        83
#      Polyphagotars onemus latus       0.80      0.44      0.57         9
#   Pseudococcus comstocki Kuwana       0.72      0.33      0.46        87
#              parathrene regalis       0.79      0.61      0.69        36
#                     Ampelophaga       0.81      0.71      0.76       229
#              Lycorma delicatula       0.84      0.87      0.86      1547
#                     Xylotrechus       0.83      0.82      0.83       344
#               Cicadella viridis       0.79      0.74      0.77       382
#                         Miridae       0.74      0.81      0.78      1525
#       Trialeurodes vaporariorum       0.72      0.83      0.77       156
#           Erythroneura apicalis       0.61      0.64      0.62        22
#                  Papilio xuthus       0.94      0.92      0.93       132
#        Panonchus citri McGregor       0.64      0.74      0.69        86
#  Phyllocoptes oleiverus ashmead       0.00      0.00      0.00         2
#         Icerya purchasi Maskell       0.66      0.78      0.72       217
#              Unaspis yanonensis       0.72      0.42      0.53       125
#              Ceroplastes rubens       0.74      0.72      0.73        74
#           Chrysomphalus aonidum       0.89      0.27      0.42        62
#       Parlatoria zizyphus Lucus       0.00      0.00      0.00         5
#            Nipaecoccus vastalor       0.58      0.32      0.41        22
#        Aleurocanthus spiniferus       0.79      0.95      0.86       147
#   Tetradacus c Bactrocera minax       0.69      0.76      0.73        97
#          Dacus dorsalis(Hendel)       0.65      0.63      0.64       112
#            Bactrocera tsuneonis       0.46      0.34      0.39        47
#                 Prodenia litura       0.66      0.64      0.65       333
#                   Adristyrannus       0.67      0.62      0.65        90
# Phyllocnistis citrella Stainton       0.80      0.67      0.73        72
#            Toxoptera citricidus       0.33      0.29      0.31        55
#              Toxoptera aurantii       0.56      0.48      0.52        56
#     Aphis citricola Vander Goot       0.61      0.61      0.61       106
#      Scirtothrips dorsalis Hood       0.76      0.71      0.73       143
#                    Dasineura sp       0.37      0.27      0.31        41
#         Lawana imitata Melichar       0.69      0.80      0.74       174
#       Salurnis marginella Guerr       0.82      0.77      0.79       146
#      Deporaus marginatus Pascoe       0.67      0.51      0.58        63
#            Chlumetia transversa       0.46      0.42      0.44        77
#      Mango flat beak leafhopper       0.43      0.29      0.34        21
#      Rhytidodera bowrinii white       0.67      0.60      0.63       165
#           Sternochetus frigidus       0.62      0.61      0.62       132
#                    Cicadellidae       0.83      0.86      0.84      1721
#
#                        accuracy                           0.70     20047
#                       macro avg       0.61      0.57      0.58     20047
#                    weighted avg       0.69      0.70      0.69     20047

# %%
#Get the filename including last folder
image_names = [os.path.basename(filename) for filename in test_batchs_Res.filenames]


# Get the image names from the ImageDataGenerator
image_names = test_batchs_Res.filenames

df = pd.DataFrame({'Image Name': image_names, 'Predicted': y_pred_Res, 'Ground Truth': y_true_Res})
df.to_csv('results_R50_cls_no_aug.csv', index=False)

# %%
matRes = confusion_matrix(y_true_Res,y_pred_Res)
plot_confusion_matrix(matRes, figsize=(36,36), class_names=classes, show_normed=True)
# Out:
# (<Figure size 3600x3600 with 1 Axes>,
#  <Axes: xlabel='predicted label', ylabel='true label'>)
