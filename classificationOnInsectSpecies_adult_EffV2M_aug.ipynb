# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
import pathlib
import glob
import itertools
import pandas as pd
import seaborn as sns



from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.layers import Conv2D, Flatten, Dense, MaxPooling2D, BatchNormalization, GlobalAveragePooling2D, Dropout
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.applications.efficientnet_v2 import EfficientNetV2M
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import RMSprop
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import classification_report
from mlxtend.plotting import plot_confusion_matrix

# %%
train_data_dir = r"D:/experiments/Datasets/ip102_v1.1-002/ip102_v1.1/prepared_data/train_cls_adult/"
valid_data_dir = r"D:/experiments/Datasets/ip102_v1.1-002/ip102_v1.1/prepared_data/val_cls_adult/"
test_data_dir = r"D:/experiments/Datasets/ip102_v1.1-002/ip102_v1.1/prepared_data/test_cls_adult/"

# %%
classes = ['rice leaf roller',
        'rice leaf caterpillar',
        'paddy stem maggot',
        'asiatic rice borer',
        'yellow rice borer',
        'rice gall midge',
        'Rice Stemfly',
        'brown plant hopper',
        'white backed plant hopper',
        'small brown plant hopper',
        'rice water weevil',
        'rice leafhopper',
        'grain spreader thrips',
        'rice shell pest',
        'grub',
        'mole cricket',
        'wireworm',
        'white margined moth',
        'black cutworm',
        'large cutworm',
        'yellow cutworm',
        'red spider',
        'corn borer',
        'army worm',
        'aphids',
        'Potosiabre vitarsis',
        'peach borer',
        'english grain aphid',
        'green bug',
        'bird cherry-oataphid',
        'wheat blossom midge',
        'penthaleus major',
        'longlegged spider mite',
        'wheat phloeothrips',
        'wheat sawfly',
        'cerodonta denticornis',
        'beet fly',
        'flea beetle',
        'cabbage army worm',
        'beet army worm',
        'Beet spot flies',
        'meadow moth',
        'beet weevil',
        'sericaorient alismots chulsky',
        'alfalfa weevil',
        'flax budworm',
        'alfalfa plant bug',
        'tarnished plant bug',
        'Locustoidea',
        'lytta polita',
        'legume blister beetle',
        'blister beetle',
        'therioaphis maculata Buckton',
        'odontothrips loti',
        'Thrips',
        'alfalfa seed chalcid',
        'Pieris canidia',
        'Apolygus lucorum',
        'Limacodidae',
        'Viteus vitifoliae',
        'Colomerus vitis',
        'Brevipoalpus lewisi McGregor',
        'oides decempunctata',
        'Polyphagotars onemus latus',
        'Pseudococcus comstocki Kuwana',
        'parathrene regalis',
        'Ampelophaga',
        'Lycorma delicatula',
        'Xylotrechus',
        'Cicadella viridis',
        'Miridae',
        'Trialeurodes vaporariorum',
        'Erythroneura apicalis',
        'Papilio xuthus',
        'Panonchus citri McGregor',
        'Phyllocoptes oleiverus ashmead',
        'Icerya purchasi Maskell',
        'Unaspis yanonensis',
        'Ceroplastes rubens',
        'Chrysomphalus aonidum',
        'Parlatoria zizyphus Lucus',
        'Nipaecoccus vastalor',
        'Aleurocanthus spiniferus',
        'Tetradacus c Bactrocera minax',
        'Dacus dorsalis(Hendel)',
        'Bactrocera tsuneonis',
        'Prodenia litura',
        'Adristyrannus',
        'Phyllocnistis citrella Stainton',
        'Toxoptera citricidus',
        'Toxoptera aurantii',
        'Aphis citricola Vander Goot',
        'Scirtothrips dorsalis Hood',
        'Dasineura sp',
        'Lawana imitata Melichar',
        'Salurnis marginella Guerr',
        'Deporaus marginatus Pascoe',
        'Chlumetia transversa',
        'Mango flat beak leafhopper',
        'Rhytidodera bowrinii white',
        'Sternochetus frigidus',
        'Cicadellidae'
]

# %% [markdown]
# # Efficientnet

# %%
datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    vertical_flip=True,
    horizontal_flip=True,
    fill_mode='nearest'
)

# %%
# datagen = ImageDataGenerator()

# %%
train_batchs_Res = datagen.flow_from_directory(directory=train_data_dir, target_size=(224,224), classes=classes, batch_size=64)

valid_batchs_Res = datagen.flow_from_directory(directory=valid_data_dir, target_size=(224,224), classes=classes, batch_size=64)

test_batchs_Res = datagen.flow_from_directory(directory=test_data_dir, target_size=(224,224), classes=classes, batch_size=64, shuffle=False)
# Out:
# Found 31003 images belonging to 102 classes.
# Found 5137 images belonging to 102 classes.
# Found 16177 images belonging to 102 classes.

# %%
base_model_Res = EfficientNetV2M(include_top = False, weights = 'imagenet',input_shape=(224, 224, 3))

for layer in base_model_Res.layers:
    layer.trainable = True

# %%
x = base_model_Res.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)

predictions = Dense(train_batchs_Res.num_classes, activation='softmax')(x)

modelRes = Model(inputs=base_model_Res.input, outputs=predictions)

# %%
modelRes.compile(optimizer = Adam(learning_rate=0.0001), loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
callbacks = [
        ModelCheckpoint("SavedModels/EfficientNetV2M/EfficientNetV2M_adult_cls_Adam_aug.h5", verbose=1, save_best_model=True),
        ReduceLROnPlateau(monitor="val_loss", patience=3, factor=0.1, verbose=1, min_lr=1e-6),
        EarlyStopping(monitor="val_loss", patience=5, verbose=1)
    ]

# %%
history_Res = modelRes.fit(x = train_batchs_Res, 
            steps_per_epoch=train_batchs_Res.samples // 64,
            validation_data = valid_batchs_Res,
            validation_steps=valid_batchs_Res.samples // 64,
            epochs = 500, verbose = 1,
            callbacks=callbacks,)
# Out:
# Epoch 1/500
# 484/484 [==============================] - ETA: 0s - loss: 2.3234 - accuracy: 0.4576
# Epoch 1: saving model to SavedModels/EfficientNetV2M\EfficientNetV2M_adult_cls_Adam_aug.h5
# 484/484 [==============================] - 315s 625ms/step - loss: 2.3234 - accuracy: 0.4576 - val_loss: 1.5175 - val_accuracy: 0.6027 - lr: 1.0000e-04
# Epoch 2/500
# 484/484 [==============================] - ETA: 0s - loss: 1.1691 - accuracy: 0.6725
# Epoch 2: saving model to SavedModels/EfficientNetV2M\EfficientNetV2M_adult_cls_Adam_aug.h5
# 484/484 [==============================] - 176s 362ms/step - loss: 1.1691 - accuracy: 0.6725 - val_loss: 1.2378 - val_accuracy: 0.6625 - lr: 1.0000e-04
# Epoch 3/500
# 484/484 [==============================] - ETA: 0s - loss: 0.8693 - accuracy: 0.7464
# Epoch 3: saving model to SavedModels/EfficientNetV2M\EfficientNetV2M_adult_cls_Adam_aug.h5
# 484/484 [==============================] - 183s 378ms/step - loss: 0.8693 - accuracy: 0.7464 - val_loss: 1.1338 - val_accuracy: 0.6979 - lr: 1.0000e-04
# Epoch 4/500
# 484/484 [==============================] - ETA: 0s - loss: 0.6888 - accuracy: 0.7913
# Epoch 4: saving model to SavedModels/EfficientNetV2M\EfficientNetV2M_adult_cls_Adam_aug.h5
# 484/484 [==============================] - 183s 377ms/step - loss: 0.6888 - accuracy: 0.7913 - val_loss: 1.0945 - val_accuracy: 0.7168 - lr: 1.0000e-04
# Epoch 5/500
# 484/484 [==============================] - ETA: 0s - loss: 0.5725 - accuracy: 0.8230
# Epoch 5: saving model to SavedModels/EfficientNetV2M\EfficientNetV2M_adult_cls_Adam_aug.h5
# 484/484 [==============================] - 182s 375ms/step - loss: 0.5725 - accuracy: 0.8230 - val_loss: 1.3039 - val_accuracy: 0.6670 - lr: 1.0000e-04
# Epoch 6/500
# 484/484 [==============================] - ETA: 0s - loss: 0.4729 - accuracy: 0.8487
# Epoch 6: saving model to SavedModels/EfficientNetV2M\EfficientNetV2M_adult_cls_Adam_aug.h5
# 484/484 [==============================] - 182s 376ms/step - loss: 0.4729 - accuracy: 0.8487 - val_loss: 1.1778 - val_accuracy: 0.7037 - lr: 1.0000e-04
# Epoch 7/500
# 484/484 [==============================] - ETA: 0s - loss: 0.3924 - accuracy: 0.8740
# Epoch 7: saving model to SavedModels/EfficientNetV2M\EfficientNetV2M_adult_cls_Adam_aug.h5
# 484/484 [==============================] - 183s 378ms/step - loss: 0.3924 - accuracy: 0.8740 - val_loss: 1.0889 - val_accuracy: 0.7287 - lr: 1.0000e-04
# Epoch 8/500
# 484/484 [==============================] - ETA: 0s - loss: 0.3384 - accuracy: 0.8883
# Epoch 8: saving model to SavedModels/EfficientNetV2M\EfficientNetV2M_adult_cls_Adam_aug.h5
# 484/484 [==============================] - 182s 374ms/step - loss: 0.3384 - accuracy: 0.8883 - val_loss: 1.3686 - val_accuracy: 0.6844 - lr: 1.0000e-04
# Epoch 9/500
# 484/484 [==============================] - ETA: 0s - loss: 0.3011 - accuracy: 0.8980
# Epoch 9: saving model to SavedModels/EfficientNetV2M\EfficientNetV2M_adult_cls_Adam_aug.h5
# 484/484 [==============================] - 187s 386ms/step - loss: 0.3011 - accuracy: 0.8980 - val_loss: 1.3035 - val_accuracy: 0.7076 - lr: 1.0000e-04
# Epoch 10/500
# 484/484 [==============================] - ETA: 0s - loss: 0.2604 - accuracy: 0.9117
# Epoch 10: saving model to SavedModels/EfficientNetV2M\EfficientNetV2M_adult_cls_Adam_aug.h5
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 484/484 [==============================] - 183s 377ms/step - loss: 0.2604 - accuracy: 0.9117 - val_loss: 1.2055 - val_accuracy: 0.7408 - lr: 1.0000e-04
# Epoch 11/500
# 484/484 [==============================] - ETA: 0s - loss: 0.1785 - accuracy: 0.9406
# Epoch 11: saving model to SavedModels/EfficientNetV2M\EfficientNetV2M_adult_cls_Adam_aug.h5
# 484/484 [==============================] - 183s 378ms/step - loss: 0.1785 - accuracy: 0.9406 - val_loss: 1.0907 - val_accuracy: 0.7621 - lr: 1.0000e-05
# Epoch 12/500
# 484/484 [==============================] - ETA: 0s - loss: 0.1472 - accuracy: 0.9505
# Epoch 12: saving model to SavedModels/EfficientNetV2M\EfficientNetV2M_adult_cls_Adam_aug.h5
# 484/484 [==============================] - 183s 378ms/step - loss: 0.1472 - accuracy: 0.9505 - val_loss: 1.1011 - val_accuracy: 0.7670 - lr: 1.0000e-05
# Epoch 12: early stopping

# %%
Res_model = tf.keras.models.load_model('SavedModels/EfficientNetV2M/EfficientNetV2M_adult_cls_Adam_aug.h5')

Res_predictions = Res_model.predict(x=test_batchs_Res, verbose=0)

# %%
y_pred_Res = np.argmax(Res_predictions, axis=1)
y_true_Res = test_batchs_Res.classes

accuracy = accuracy_score(y_true_Res, y_pred_Res)
print('Accuracy: %f' % accuracy)

precision = precision_score(y_true_Res, y_pred_Res, average='weighted', zero_division=0)
print('Precision: %f' % precision)

recall = recall_score(y_true_Res, y_pred_Res, average='weighted', zero_division=0)
print('Recall: %f' % recall)

f1 = f1_score(y_true_Res, y_pred_Res, average='weighted', zero_division=0)
print('F1 score: %f' % f1)
# Out:
# Accuracy: 0.747481
# Precision: 0.744545
# Recall: 0.747481
# F1 score: 0.742833

# %%
#Get the filename including last folder
image_names = [os.path.basename(filename) for filename in test_batchs_Res.filenames]


# Get the image names from the ImageDataGenerator
image_names = test_batchs_Res.filenames

df = pd.DataFrame({'Image Name': image_names, 'Predicted': y_pred_Res, 'Ground Truth': y_true_Res})
df.to_csv('EfficientNetV2M_adult_cls_Adam_aug.csv', index=False)

# %%
print(classification_report(y_true_Res, y_pred_Res, target_names=classes,zero_division=0))
# Out:
#                                  precision    recall  f1-score   support
#
#                rice leaf roller       0.74      0.91      0.82        47
#           rice leaf caterpillar       0.59      0.43      0.49        47
#               paddy stem maggot       0.29      0.19      0.23        26
#              asiatic rice borer       0.69      0.62      0.65        65
#               yellow rice borer       0.78      0.90      0.83        58
#                 rice gall midge       0.73      0.84      0.78       105
#                    Rice Stemfly       0.57      0.47      0.52        34
#              brown plant hopper       0.65      0.48      0.55       183
#       white backed plant hopper       0.63      0.59      0.61       155
#        small brown plant hopper       0.57      0.59      0.58        87
#               rice water weevil       0.79      0.76      0.77       154
#                 rice leafhopper       0.43      0.50      0.46       109
#           grain spreader thrips       0.48      0.62      0.54        52
#                 rice shell pest       0.46      0.43      0.44        14
#                            grub       0.00      0.00      0.00         1
#                    mole cricket       0.95      0.98      0.97       483
#                        wireworm       0.64      0.77      0.70        39
#             white margined moth       0.65      0.72      0.68        18
#                   black cutworm       0.72      0.72      0.72        60
#                   large cutworm       0.33      0.47      0.39        36
#                  yellow cutworm       0.56      0.69      0.62        42
#                      red spider       0.66      0.66      0.66       148
#                      corn borer       0.86      0.75      0.80       114
#                       army worm       0.33      0.17      0.23        35
#                          aphids       0.72      0.80      0.76      1229
#             Potosiabre vitarsis       0.87      0.94      0.91       163
#                     peach borer       0.98      0.94      0.96        64
#             english grain aphid       0.37      0.37      0.37       197
#                       green bug       0.31      0.33      0.32        98
#            bird cherry-oataphid       0.38      0.42      0.40       213
#             wheat blossom midge       0.93      0.60      0.73        95
#                penthaleus major       0.73      0.59      0.65        63
#          longlegged spider mite       0.52      0.51      0.51        51
#              wheat phloeothrips       0.56      0.62      0.59        74
#                    wheat sawfly       0.85      0.66      0.74        61
#           cerodonta denticornis       0.38      0.38      0.38        24
#                        beet fly       0.52      0.46      0.49        24
#                     flea beetle       0.84      0.87      0.86       237
#               cabbage army worm       0.51      0.44      0.48        79
#                  beet army worm       0.52      0.49      0.51        94
#                 Beet spot flies       0.60      0.54      0.57        59
#                     meadow moth       0.67      0.68      0.68        63
#                     beet weevil       0.57      0.59      0.58        93
#   sericaorient alismots chulsky       0.80      0.78      0.79        50
#                  alfalfa weevil       0.69      0.55      0.61        83
#                    flax budworm       0.49      0.46      0.48       138
#               alfalfa plant bug       0.52      0.51      0.52       197
#             tarnished plant bug       0.61      0.54      0.58       237
#                     Locustoidea       0.89      0.93      0.91       419
#                    lytta polita       0.62      0.50      0.55       197
#           legume blister beetle       0.70      0.81      0.75       423
#                  blister beetle       0.71      0.66      0.68       568
#    therioaphis maculata Buckton       0.31      0.23      0.26        44
#               odontothrips loti       0.70      0.61      0.65        54
#                          Thrips       0.37      0.31      0.34        64
#            alfalfa seed chalcid       0.52      0.54      0.53        52
#                  Pieris canidia       0.96      0.96      0.96       138
#                Apolygus lucorum       0.41      0.47      0.44       102
#                     Limacodidae       0.94      0.53      0.68        60
#               Viteus vitifoliae       0.00      0.00      0.00        18
#                 Colomerus vitis       0.00      0.00      0.00        35
#    Brevipoalpus lewisi McGregor       1.00      0.33      0.50         9
#             oides decempunctata       0.93      0.98      0.95        83
#      Polyphagotars onemus latus       1.00      0.67      0.80         6
#   Pseudococcus comstocki Kuwana       0.61      0.38      0.47        78
#              parathrene regalis       0.53      0.73      0.62        22
#                     Ampelophaga       0.85      0.69      0.76       159
#              Lycorma delicatula       0.88      0.90      0.89      1540
#                     Xylotrechus       0.87      0.86      0.86       344
#               Cicadella viridis       0.81      0.83      0.82       372
#                         Miridae       0.82      0.83      0.83      1525
#       Trialeurodes vaporariorum       0.81      0.86      0.83       137
#           Erythroneura apicalis       0.67      0.64      0.65        22
#                  Papilio xuthus       0.97      0.97      0.97       119
#        Panonchus citri McGregor       0.65      0.80      0.72        86
#  Phyllocoptes oleiverus ashmead       0.00      0.00      0.00         1
#         Icerya purchasi Maskell       0.70      0.85      0.77       217
#              Unaspis yanonensis       0.70      0.44      0.54       124
#              Ceroplastes rubens       0.69      0.74      0.71        74
#           Chrysomphalus aonidum       0.85      0.29      0.44        58
#       Parlatoria zizyphus Lucus       0.00      0.00      0.00         5
#            Nipaecoccus vastalor       0.00      0.00      0.00        22
#        Aleurocanthus spiniferus       0.82      0.78      0.80        18
#   Tetradacus c Bactrocera minax       0.55      0.53      0.54        30
#          Dacus dorsalis(Hendel)       0.80      0.84      0.82        90
#            Bactrocera tsuneonis       0.36      0.53      0.43        30
#                 Prodenia litura       0.69      0.69      0.69       109
#                   Adristyrannus       0.65      0.79      0.72        68
# Phyllocnistis citrella Stainton       0.88      0.68      0.77        22
#            Toxoptera citricidus       0.48      0.36      0.41        55
#              Toxoptera aurantii       0.58      0.55      0.57        56
#     Aphis citricola Vander Goot       0.53      0.68      0.60       106
#      Scirtothrips dorsalis Hood       0.81      0.68      0.74       142
#                    Dasineura sp       0.50      0.33      0.40        18
#         Lawana imitata Melichar       0.72      0.83      0.77       174
#       Salurnis marginella Guerr       0.77      0.79      0.78       146
#      Deporaus marginatus Pascoe       0.75      0.60      0.67        63
#            Chlumetia transversa       0.38      0.46      0.41        39
#      Mango flat beak leafhopper       0.64      0.33      0.44        21
#      Rhytidodera bowrinii white       0.76      0.68      0.72       164
#           Sternochetus frigidus       0.62      0.68      0.64       130
#                    Cicadellidae       0.86      0.89      0.87      1721
#
#                        accuracy                           0.75     16177
#                       macro avg       0.62      0.59      0.60     16177
#                    weighted avg       0.74      0.75      0.74     16177

# %%
matRes = confusion_matrix(y_true_Res,y_pred_Res)
plot_confusion_matrix(matRes, figsize=(36,36), class_names=classes, show_normed=True)
# Out:
# (<Figure size 3600x3600 with 1 Axes>,
#  <Axes: xlabel='predicted label', ylabel='true label'>)
